# %%
from bs4 import BeautifulSoup
import requests

import numpy as np
import pandas as pd

import csv

# %% [markdown]
# > content = res.content
#
# > /html/body/div/div[5]/div[1]/ul/li[3]/h2/a
# > /html/body/div/div[5]/div[1]/ul/li[42]/h2/a
#
# > eg:
# > <a title="Suzuki Alto 2015 Car" href="https://riyasewana.com/buy/suzuki-alto-sale-batticaloa-7157886">Suzuki Alto 2015 Car</a>
#
# >

# %%
base_url = "https://riyasewana.com/search/cars?page="
total_pages = 323
all_data = []

# Function to scrape data from a given page
def scrape_page(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Referer': 'https://www.google.com/',
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        car_elements = soup.select('li.item.round:not(.promoted) h2 a')
        data = []
        for car_element in car_elements:
            car_name = car_element.get('title')
            car_link = car_element.get('href')
            data.append({'Car Name': car_name, 'Car Link': car_link})
        return data
    else:
        print(f"Failed to fetch page {url}. Status code: {response.status_code}")
        return []

# For 1st page
page_url = "https://riyasewana.com/search/cars"
print(f"Scraping data from {page_url}...")
data = scrape_page(page_url)
all_data.extend(data)

# # For rest of the pages
for page_number in range(2, total_pages + 1):
    page_url = f"{base_url}{page_number}"
    print(f"Scraping data from {page_url}...")
    data = scrape_page(page_url)
    all_data.extend(data)

    # Save data to CSV
    csv_file_path = "car_data.csv"
    with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Car Name', 'Car Link']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(all_data)

    print(f"Data saved to {csv_file_path}")
# Out:
# Scraping data from https://riyasewana.com/search/cars...
# Scraping data from https://riyasewana.com/search/cars?page=2...
# Data saved to car_data.csv
# Scraping data from https://riyasewana.com/search/cars?page=3...
# Data saved to car_data.csv
# Scraping data from https://riyasewana.com/search/cars?page=4...
# Data saved to car_data.csv
# Scraping data from https://riyasewana.com/search/cars?page=5...
# Data saved to car_data.csv
# Scraping data from https://riyasewana.com/search/cars?page=6...
# Data saved to car_data.csv
# Scraping data from https://riyasewana.com/search/cars?page=7...
# Data saved to car_data.csv
# Scraping data from https://riyasewana.com/search/cars?page=8...
# Data saved to car_data.csv
# Scraping data from https://riyasewana.com/search/cars?page=9...
# Data saved to car_data.csv
# Scraping data from https://riyasewana.com/search/cars?page=10...
# Data saved to car_data.csv
# Scraping data from https://riyasewana.com/search/cars?page=11...
# ...

# %%
import requests
from bs4 import BeautifulSoup
import csv
from multiprocessing import Pool

base_url = "https://riyasewana.com/search/cars?page="
total_pages = 323
all_data = []

# Function to scrape data from a given page
def scrape_page(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Referer': 'https://www.google.com/',
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        car_elements = soup.select('li.item.round:not(.promoted) h2 a')
        data = []
        for car_element in car_elements:
            car_name = car_element.get('title')
            car_link = car_element.get('href')
            data.append({'Car Name': car_name, 'Car Link': car_link})
        return data
    else:
        print(f"Failed to fetch page {url}. Status code: {response.status_code}")
        return []

def scrape_page_wrapper(page_number):
    page_url = f"{base_url}{page_number}"
    print(f"Scraping data from {page_url}...")
    return scrape_page(page_url)

def main():
    # Use a Pool to parallelize the scraping
    with Pool() as pool:
        # For 1st page
        page_url = "https://riyasewana.com/search/cars"
        print(f"Scraping data from {page_url}...")
        data = scrape_page(page_url)
        all_data.extend(data)

        # For rest of the pages
        page_numbers = range(2, total_pages + 1)
        all_data.extend(pool.map(scrape_page_wrapper, page_numbers))

    # Save data to CSV
    csv_file_path = "car_data.csv"
    with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Car Name', 'Car Link']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(all_data)

    print(f"Data saved to {csv_file_path}")

if __name__ == "__main__":
    main()
# Out:
# Scraping data from https://riyasewana.com/search/cars...

# %%
len(data)
# Out:
# 40
